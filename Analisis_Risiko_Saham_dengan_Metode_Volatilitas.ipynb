# %% [markdown]
# <a href="https://colab.research.google.com/github/Maulcepling20/Stock-Analysis-Using-Statistical-Volatility-Methods/blob/main/Analisis_Risiko_Saham_dengan_Metode_Volatilitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analisis ini bertujuan untuk mengetahui jenis saham yang memiliki risiko pergerakan paling rendah berdasarkan persentase dari hasil perhitungan volatility harian dan tahunan. Sampel data saham yang digunakan yaitu BRI, BCA, Mandiri, Astra, Telkom, Pakuwon Jati, Indomie, Indofood, Mayora, dan Eiger. Dataset diperoleh dari situs resmi Bursa Efek Indonesia, melalui Muamkh, IHSG Stock Data, tersedia di https://www.kaggle.com/datasets/muamkh/ihsgstockdata
# , dilisensikan di bawah CC BY-NC 4.0.. Analisis ini hanya sebagai bahan edukasi dan untuk menambah literatur terkait research khususnya pada metode volatilitas statistik, dan tidak bermaksud untuk menjelekan atau menjatuhkan salah satu perusahaan yang digunakan sebagai sampel penelitian.

# %% [markdown]
# #A. Install Package yang Diperlukan

# %%
# !pip install arch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 19.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# #B. Analisis Data per Sampel Saham

# %% [markdown]
# ###1. Saham BRI

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('BBRI.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

data.set_index('date', inplace=True)

# Pengecekan nilai kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

# Hapus baris dengan nilai NaN
data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean        0.050704
# std         2.127543
# min        -7.812500
# 25%        -0.995050
# 50%         0.000000
# 75%         0.980392
# max        20.491803
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###2. Saham BCA

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('BBCA.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean       -0.019502
# std         2.865263
# min       -79.439891
# 25%        -0.763069
# 50%         0.000000
# 75%         0.814113
# max        17.333333
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###3. Saham MANDIRI

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('BMRI.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean        0.031325
# std         2.613495
# min       -50.593824
# 25%        -0.971676
# 50%         0.000000
# 75%         1.142961
# max        15.803109
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###4. Saham ASTRA

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('ASII.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pergecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean       -0.007714
# std         2.118142
# min       -11.453744
# 25%        -1.167315
# 50%         0.000000
# 75%         1.102941
# max        12.707182
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###5. Saham TELKOM

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('TLKM.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean        0.015981
# std         1.912517
# min        -9.695291
# 25%        -1.004185
# 50%         0.000000
# 75%         0.993803
# max        13.740458
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###6. Saham PAKUWON JATI

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('PWON.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean       -0.017359
# std         2.494867
# min        -9.638554
# 25%        -1.351351
# 50%         0.000000
# 75%         1.066848
# max        20.930233
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###7. Saham INDOMIE

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('ICBP.csv')

# Tampilkan Variabel

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean        0.023290
# std         1.749593
# min        -8.874459
# 25%        -0.855922
# 50%         0.000000
# 75%         0.795756
# max        14.457831
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###8. Saham INDOFOOD

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('INDF.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean        0.013341
# std         1.777445
# min        -8.794788
# 25%        -0.795232
# 50%         0.000000
# 75%         0.811362
# max        18.316832
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###9. Saham MAYORA

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('MYOR.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    1119.000000
# mean        0.021515
# std         2.096907
# min        -8.771930
# 25%        -1.065723
# 50%         0.000000
# 75%         0.857756
# max        21.118012
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# ...

# %% [markdown]
# ###10. Saham EIGER

# %%
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

data = pd.read_csv('EDGE.csv')

# Tampilkan Variabel
print(data.columns)

# Ubah tipe data kolom tanggal ke tipe datetime
data['date'] = pd.to_datetime(data['date'])

# Atur kolom tanggal sebagai index
data.set_index('date', inplace=True)

# Pengecekan Nilai Kosong
print(f"Jumlah nilai NaN di 'close': {data['close'].isna().sum()}")
print(f"Jumlah nilai nol di 'close': {(data['close'] == 0).sum()}")

# Hitung return harian
data['Return'] = data['close'].pct_change() * 100

data.dropna(subset=['Return'], inplace=True)

print(data['Return'].describe())

# Pastikan ada cukup data untuk model
if len(data) > 1:
    # Model GARCH(1,1)
    model = arch_model(data['Return'], vol='Garch', p=1, q=1)

    # Fitting model
    model_fit = model.fit(disp='off')

    # Summarize model
    print(model_fit.summary())

    # Plot volatilitas hasil prediksi
    fig = model_fit.plot(annualize='D')
    plt.show()
else:
    print("Data tidak cukup untuk membuat model GARCH.")
# Out:
# Index(['date', 'previous', 'open_price', 'first_trade', 'high', 'low', 'close',
#        'change', 'volume', 'value', 'frequency', 'index_individual', 'offer',
#        'offer_volume', 'bid', 'bid_volume', 'listed_shares', 'tradeble_shares',
#        'weight_for_index', 'foreign_sell', 'foreign_buy', 'delisting_date',
#        'non_regular_volume', 'non_regular_value', 'non_regular_frequency'],
#       dtype='object')
# Jumlah nilai NaN di 'close': 0
# Jumlah nilai nol di 'close': 0
# count    743.000000
# mean       0.128046
# std        5.595991
# min      -80.000000
# 25%       -1.114034
# 50%        0.000000
# 75%        0.560624
# max       25.000000
# Name: Return, dtype: float64
#                      Constant Mean - GARCH Model Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2037.27
# ...

# %% [markdown]
# #C. Analisis Volatilitas untuk Harian dan Tahunan Menggunakan Seluruh Sampel Data

# %%
import numpy as np

# Define GARCH parameters
params = {
    'BBRI': {'alpha': 0.0874, 'beta': 0.8835, 'omega': 0.1136},
    'BBCA': {'alpha': 0.1568, 'beta': 0.8432, 'omega': 0.3187},
    'BMRI': {'alpha': 0.1803, 'beta': 0.8197, 'omega': 0.2015},
    'ASII': {'alpha': 0.0680, 'beta': 0.8986, 'omega': 0.1395},
    'TLKM': {'alpha': 0.1379, 'beta': 0.7646, 'omega': 0.3405},
    'PWON': {'alpha': 0.0570, 'beta': 0.9344, 'omega': 0.0511},
    'ICBP': {'alpha': 0.2715, 'beta': 0.4166, 'omega': 0.9593},
    'INDF': {'alpha': 0.1617, 'beta': 0.7397, 'omega': 0.2657},
    'MYOR': {'alpha': 0.1525, 'beta': 0.7573, 'omega': 0.3990},
    'EDGE': {'alpha': 0.4683, 'beta': 0.5317, 'omega': 1.5632},

}

# Adjust parameters if necessary
for stock, param in params.items():
    if param['alpha'] + param['beta'] >= 1:
        param['beta'] = 0.999 - param['alpha']

# Function to calculate daily and annual volatility
def calculate_volatility(alpha, beta, omega):
    # Steady-state variance of GARCH(1,1)
    var_daily = omega / (1 - alpha - beta)
    std_daily = np.sqrt(var_daily)
    # Annualize the volatility
    std_annual = std_daily * np.sqrt(252)
    return std_daily, std_annual

# Calculate and print volatilities
volatility_results = {}
for stock, param in params.items():
    std_daily, std_annual = calculate_volatility(param['alpha'], param['beta'], param['omega'])
    volatility_results[stock] = {'Daily Volatility': std_daily, 'Annual Volatility': std_annual}

volatility_results
# Out:
# {'BBRI': {'Daily Volatility': 1.9757985901221107,
#   'Annual Volatility': 31.364830261290866},
#  'BBCA': {'Daily Volatility': 17.85217073635683,
#   'Annual Volatility': 283.39442478639},
#  'BMRI': {'Daily Volatility': 14.195069566578384,
#   'Annual Volatility': 225.339743498567},
#  'ASII': {'Daily Volatility': 2.043684590778829,
#   'Annual Volatility': 32.442487112733524},
#  'TLKM': {'Daily Volatility': 1.8687717068458873,
#   'Annual Volatility': 29.665831160807517},
#  'PWON': {'Daily Volatility': 2.437593170550886,
#   'Annual Volatility': 38.695591960962595},
#  'ICBP': {'Daily Volatility': 1.753757473920633,
#   'Annual Volatility': 27.840036815489036},
#  'INDF': {'Daily Volatility': 1.6415621116267882,
#   'Annual Volatility': 26.058990654183198},
#  'MYOR': {'Daily Volatility': 2.1032126202413175,
#   'Annual Volatility': 33.38746528470635},
#  'EDGE': {'Daily Volatility': 39.5373241380828,
#   'Annual Volatility': 627.6355630459095}}

# %% [markdown]
# #D. Kesimpulan

# %% [markdown]
# Berdasarkan hasil analisis volatilitas statistik harian dan tahunan diatas, diperoleh bahwa untuk saham yang memiliki pergerakan paling tinggi baik pada pergerakan harian maupun tahunan yaitu saham Eiger, dengan nilai volatilitas hariannya sebesar 39% dan tahunannya sebesar 627%, sedangkan untuk saham dengan pergerakan paling rendah yaitu Indofood dengan nilai volatilitas hariannya sebesar 1,6% dan tahunannya sebesar 26%. Oleh karena itu, dapat disimpulkan bahwa nilai saham yang memiliki risiko fluktuasi pergerakan paling tinggi yaitu saham perusahaan Eiger, sedangkan untuk risiko fluktuasi pergerakan nilai saham paling rendah yaitu pada perusahaan Indofood.

# %% [markdown]
# Research ini masih memiliki banyak kekurangan, oleh karena itu untuk peneliti selanjutnya yang akan melakukan penelitian terkait analisis risiko saham dapat mencoba dengan metode lain, dengan tujuan untuk menambah referensi penelitian terkait analisis risiko pergerakan saham.
